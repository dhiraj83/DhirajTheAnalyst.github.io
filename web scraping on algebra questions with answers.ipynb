# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
url='https://www.geeksforgeeks.org/algebra-questions/'

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

# %%
page= requests.get(url, headers=headers)

# %%
soup1=BeautifulSoup(page.content, 'html.parser')

# %%
soup2=BeautifulSoup(soup1.prettify(), 'html.parser')

# %%
Q1=soup1.find('div',class_='text',).get_text()

# %%
Q1
# Out:
# '\nAlgebra is the basis for calculus, geometry, trigonometry, and statistics. The students of class 6, 7, 8, and 9 need to improve their understanding of algebraic principles. This would require practicing as many Questions as possible. These algebra Questions should cover a range of topics, including linear equations, quadratic equations, polynomials, etc. \nIn this article, we have provided you with a list of Questions on Algebra. Solving these Questions will help you understand the concepts thoroughly and easily.\nAlgebra Questions with Solutions\nFollowing are some of the algebra questions along with their solutions:\nQuestion 1: If there are 2 apples in a bag and x apples are added to it, making a total of 10 apples, how many apples were added?\nSolution:\n\nLet the number of apples added be x.\nThe total number of apples is 2 (initial) + x (added) = 10.\nSo, 2 + x = 10.\nSubtract 2 from both sides to find x: x = 10 – 2.\nTherefore, x = 8 apples were added.\n\nQuestion 2: A pen 
# ...

# %%
soup1.find('div',class_='text')
# Out:
# <div class="text">
# <p dir="ltr"><b><strong>Algebra</strong></b><span> is the basis for calculus, geometry, trigonometry, and statistics. The students of class 6, 7, 8, and 9 need to improve their understanding of algebraic principles. This would require practicing as many Questions as possible. These algebra Questions should cover a range of topics, including linear equations, quadratic equations, polynomials, etc. </span></p>
# <p dir="ltr"><span>In this article, we have provided you with a list of Questions on </span><a href="https://www.geeksforgeeks.org/algebra/" rel="noopener" target="_blank"><span>Algebra</span></a><span>. Solving these Questions will help you understand the concepts thoroughly and easily.</span></p><div id="GFG_AD_gfg_mobile_336x280" style="margin: 5px 0;"></div>
# <h2><span>Algebra Questions with Solutions</span></h2>
# <p dir="ltr">Following are some of the algebra questions along with their solutions:</p>
# ...

# %%
soup1.find_all('b')
# Out:
# [<b><strong>Algebra</strong></b>,
#  <b><strong>Question 1: If there are 2 apples in a bag and x apples are added to it, making a total of 10 apples, how many apples were added?</strong></b>,
#  <b><strong>Solution:</strong></b>,
#  <b><strong>Question 2: A pen costs x dollars. If 5 pens cost $15, what is the cost of one pen?</strong></b>,
#  <b><strong>Solution:</strong></b>,
#  <b><strong>Question 3: A train travels x miles in 2 hours. If it traveled 100 miles, how many miles does it travel in one hour?</strong></b>,
#  <b><strong>Solution:</strong></b>,
#  <b><strong>Question 4: If x people can complete a task in 4 hours, and 8 people can complete the same task in 2 hours, how many people were originally there?</strong></b>,
#  <b><strong>Solution:</strong></b>,
#  <b><strong>Question 5: A rectangle’s length is twice its width. If the width is x feet and the area is 50 square feet, what is the width of the rectangle?</strong></b>,
#  <b><strong>Solution:</strong></b>,
# ...

# %%
soup2.find_all('b')
# Out:
# [<b>
#  <strong>
#                Algebra
#               </strong>
#  </b>,
#  <b>
#  <strong>
#                Question 1: If there are 2 apples in a bag and x apples are added to it, making a total of 10 apples, how many apples were added?
#               </strong>
#  </b>,
#  <b>
#  <strong>
#                Solution:
#               </strong>
#  </b>,
#  <b>
#  <strong>
#                Question 2: A pen costs x dollars. If 5 pens cost $15, what is the cost of one pen?
#               </strong>
#  </b>,
#  <b>
#  <strong>
#                Solution:
#               </strong>
#  </b>,
#  <b>
#  <strong>
#                Question 3: A train travels x miles in 2 hours. If it traveled 100 miles, how many miles does it travel in one hour?
#               </strong>
#  </b>,
#  <b>
#  <strong>
#                Solution:
#               </strong>
#  </b>,
#  <b>
#  <strong>
# ...

# %%
Q=soup1.find('b').get_text()

# %%
Q
# Out:
# 'Algebra'

# %%
soup2.find_all('strong')
# Out:
# [<strong>
#                Algebra
#               </strong>,
#  <strong>
#                Question 1: If there are 2 apples in a bag and x apples are added to it, making a total of 10 apples, how many apples were added?
#               </strong>,
#  <strong>
#                Solution:
#               </strong>,
#  <strong>
#                Question 2: A pen costs x dollars. If 5 pens cost $15, what is the cost of one pen?
#               </strong>,
#  <strong>
#                Solution:
#               </strong>,
#  <strong>
#                Question 3: A train travels x miles in 2 hours. If it traveled 100 miles, how many miles does it travel in one hour?
#               </strong>,
#  <strong>
#                Solution:
#               </strong>,
#  <strong>
#                Question 4: If x people can complete a task in 4 hours, and 8 people can complete the same task in 2 hours, how many people were originally there?
#               </strong>,
#  <strong>
# ...

# %%
soup1.find_all('b')[1]
# Out:
# <b><strong>Question 1: If there are 2 apples in a bag and x apples are added to it, making a total of 10 apples, how many apples were added?</strong></b>

# %%
q1=soup1.find_all('b')[1]

# %%
question1=q1.get_text()

# %%
question1
# Out:
# 'Question 1: If there are 2 apples in a bag and x apples are added to it, making a total of 10 apples, how many apples were added?'

# %%
total_apples=10
initial_apples=2
remaining_apples=total_apples - initial_apples
print(remaining_apples,'apples were added')
# Out:
# 8 apples were added

# %%
q2=soup1.find_all('b')[3]

# %%
question2=q2.get_text()

# %%
question2
# Out:
# 'Question 2: A pen costs x dollars. If 5 pens cost $15, what is the cost of one pen?'

# %%
total_pens=5
cost_of_5_pens= 15
cost_of_1_pen=cost_of_5_pens/total_pens
print(f'cost of one pen is {cost_of_1_pen}$')
# Out:
# cost of one pen is 3.0$

# %%
url2='https://byjus.com/maths/algebra-questions/'

# %%
page2= requests.get(url2, headers=headers)

# %%
soup3=BeautifulSoup(page2.content, 'html.parser')
soup4=BeautifulSoup(soup3.prettify(), 'html.parser')

# %%
soup3.find(id='post-1304871')
# Out:
# <article class="post-1304871 page type-page status-publish hentry" id="post-1304871">
# <p>Algebra questions are provided here, with answers, for students based on Class 6 and 7 syllabi. The questions are prepared as per NCERT (CBSE) guidelines. Solving these questions will help students understand the concept very well in an easy way. Learn <a href="https://byjus.com/maths/algebra-expressions-equations/">expressions and equations of algebra</a> here.</p>
# <p>Click here to understand more about <a href="https://byjus.com/maths/algebra/">algebra</a>.</p>
# <h2>Algebra Questions for Class 6</h2>
# <p>Basic algebra deals with finding the unknown value using variables.</p>
# <p><strong>1. Soldiers are marching in a parade. There are 10 soldiers in a row. What is the rule which gives the number of soldiers, given the number of rows? </strong></p>
# <p>Solution: Let n be the number of rows</p>
# <p>Number of soldiers in a row = 10</p>
# ...

# %%
soup3.find_all('p')
# Out:
# [<p>Algebra questions are provided here, with answers, for students based on Class 6 and 7 syllabi. The questions are prepared as per NCERT (CBSE) guidelines. Solving these questions will help students understand the concept very well in an easy way. Learn <a href="https://byjus.com/maths/algebra-expressions-equations/">expressions and equations of algebra</a> here.</p>,
#  <p>Click here to understand more about <a href="https://byjus.com/maths/algebra/">algebra</a>.</p>,
#  <p>Basic algebra deals with finding the unknown value using variables.</p>,
#  <p><strong>1. Soldiers are marching in a parade. There are 10 soldiers in a row. What is the rule which gives the number of soldiers, given the number of rows? </strong></p>,
#  <p>Solution: Let n be the number of rows</p>,
#  <p>Number of soldiers in a row = 10</p>,
#  <p>Total number of soldiers = number of soldiers in a row × number of rows</p>,
#  <p>= 10n</p>,
# ...

# %%
soup4.find_all('strong')
# Out:
# [<strong>
#           1. Soldiers are marching in a parade. There are 10 soldiers in a row. What is the rule which gives the number of soldiers, given the number of rows?
#          </strong>,
#  <strong>
#           2. Leela is Radha’s younger sister. Leela is 4 years younger than Radha. Write Leela’s age with respect to Radha’s age. Take Radha’s age to be x years.
#          </strong>,
#  <strong>
#           3. If a is the side-length of the equilateral triangle, then the perimeter of the triangle will be?
#          </strong>,
#  <strong>
#           4. Give expressions for:
#          </strong>,
#  <strong>
#           (i) p multiplied by 7
#          </strong>,
#  <strong>
#           (ii) p divided by 7
#          </strong>,
#  <strong>
#           5. If Sam age is x years. Then, what is the age of Sam after 7 years?
#          </strong>,
#  <strong>
#              Terms and Coefficient
#             </strong>,
#  <strong>
# ...

# %%
abc=soup4.find_all('strong')

# %%
abc[0].get_text()
# Out:
# '\n         1. Soldiers are marching in a parade. There are 10 soldiers in a row. What is the rule which gives the number of soldiers, given the number of rows?\n        '

# %%
ab=soup3.find_all('strong')

# %%
ab[0].get_text()
# Out:
# '1. Soldiers are marching in a parade. There are 10 soldiers in a row. What is the rule which gives the number of soldiers, given the number of rows? '

# %%
l=0
for i in ab[l].get_text():
    print(ab[l].get_text())
    l+=1
# Out:
# 1. Soldiers are marching in a parade. There are 10 soldiers in a row. What is the rule which gives the number of soldiers, given the number of rows?
# 2. Leela is Radha’s younger sister. Leela is 4 years younger than Radha. Write Leela’s age with respect to Radha’s age. Take Radha’s age to be x years.
# 3. If a is the side-length of the equilateral triangle, then the perimeter of the triangle will be?
# 4. Give expressions for:
# (i) p multiplied by 7
# (ii) p divided by 7
# 5. If Sam age is x years. Then, what is the age of Sam after 7 years?
# Terms and Coefficient
# 1. Express when x and y are both squared and added.
# 2. Identify the terms in 1 + x + x2
# 3. Write the coefficients of terms y and y2 in the given expression 13 – y + 5y2.
# Like terms:
# Unlike terms:
# Monomial:
# Binomial:
# Trinomial:
# Polynomials:
# *Note:
# 4. Find which are the like and unlike terms.
# (i) 12x, 7x
# (ii) 3xy, 3y
# 5. Classify into monomials, binomials and trinomials.
# (i) 3x – 5y
# ...
